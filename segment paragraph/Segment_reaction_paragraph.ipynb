# %%
reaction_titles = ['Activity tests',
 'SCR activity evaluation',
 'Catalytic performance tests',
 'Catalytic evaluation',
 'Reaction condition',
 'Activity measurements and evaluation',
 'Catalyst tests',
 'Catalytic activity tests',
 'Catalytic performance tests',
 'Catalytic activity measurements',
 'Catalytic testing',
 'Activity measurement',
 'Catalytic activity measurements',
 'Catalyst testing for MIBK synthesis',
 'SCR activity experiments and measurements',
 'Catalytic activity test',
 'Catalytic activity measurement',
 'SCR activity test',
 'Catalyst tests',
 'Catalytic performance tests',
 'Activity measurements',
 'Catalytic activity tests',
 'NSC and NO',
 'Catalytic activity measurement',
 'Catalyst samples',
 'Catalytic performance test',
 'Test conditions',
 'Activity and stability tests',
 'Catalytic tests',
 'Activity measurement',
 'Catalytic activity',
 'Activity measurement',
 'Catalyst performance',
 'Activity measurements',
 'Catalytic activity measurements',
 'Catalyst preparation for selective catalytic reduction (SCR) of NOx with NH',
 'Catalytic activity test',
 'Catalytic N',
 'Catalytic activity and selectivity measurement',
 'Catalysis',
 'Catalytic performance test',
 'Catalytic activity test',
 'Catalytic evaluation',
 'Catalyst evaluation',
 'Catalytic activity evaluation',
 'Catalytic experiments',
 'NO',
 'Catalytic performance tests',
 'Activity measurements',
 'Catalytic activity measurement',
 'Activity test',
 'Catalytic activity and procedures',
 'Activity measurement',
 'Catalytic performance studies',
 'Catalytic tests',
 'NO',
 'Catalytic activity',
 'NO oxidation test',
 'SCR performance',
 'Catalytic activity test',
 'SCR performance',
 'Catalytic study',
 'Activity test of catalyst',
 'Catalytic tests and kinetic studies',
 'Catalytic studies',
 'Catalytic properties',
 'Activity measurement',
 'Measurement of the catalytic activity',
 'SCR activity test',
 'Catalytic experiments',
 'Catalytic activity test',
 'Catalytic performance tests',
 'SCR activity measurements',
 'Catalytic activity tests',
 'NH',
 'Catalysis',
 'Activity measurements',
 'Catalytic performance tests',
 'Catalytic measurement',
 'Catalyst activity measurement',
 'Steady state reaction experiments',
 'Catalytic activity measurements',
 'Catalytic activity test',
 'Catalytic performance evaluation',
 'Catalytic activity',
 'Catalytic activity measurements',
 'Catalytic activity measurements',
 'SCR activity',
 'Activity tests',
 'Measurements of catalytic activity in NO + CO reaction',
 'Catalytic activity measurement',
 'Experimental setup',
 'Catalytic-activity measurement',
 'Adsorption and reaction tests',
 'Catalytic evaluation',
 'Catalytic activity test',
 'Catalytic activity',
 'Catalytic activity testing',
 'Activity measurements',
 'Characterization methods',
 'Catalytic activity tests',
 'Catalytic activity measurement',
 'Reactor setup and analytical technique',
 'Catalytic activity measurement',
 'Catalytic activity measurement',
 'Catalytic activity evaluation',
 'Catalytic performance tests',
 'Reactor setup',
 'Catalytic activity measurements',
 'Catalytic activity tests',
 'Experimental system',
 'Catalyst activity measurements',
 '没有的Discussion',
 'Catalytic performance test',
 'Reactivity studies',
 'Catalyst reducibility',
 'Activity tests of catalysts',
 'Catalytic performance tests',
 'Catalytic activity test',
 'Catalytic testing',
 'NH',
 'Catalytic activity test',
 'Catalytic activity measurement',
 'Catalytic test',
 'Catalyst activity test',
 'SCR activity',
 'NH',
 'Catalytic activity measurements',
 'Soot oxidation activity',
 'Experimental procedure',
 'Catalytic reaction',
 'Catalytic test',
 'Catalytic activity test',
 'Activity evaluation of the catalysts',
 'Catalytic activity test',
 'Activity measurement',
 'Activity tests and kinetic measurements',
 'Catalytic activity measurement',
 'Active species test experiment',
 'NH',
 'Catalytic performance measurements',
 'Catalytic activity measurements',
 '没有的Analysis of carbonaceous deposits',
 'Catalyst testing',
 'Catalytic activity measurements',
 'Catalytic activity testing',
 'Catalytic activity tests',
 'Activity tests',
 'Catalytic activity test',
 'Activity test',
 'Evaluation of the catalytic activity of the surfactant-coated cordierite carrier',
 'Catalytic activity measurement',
 'Catalytic measurements',
 'Catalyst activity measurements',
 'Catalytic performance',
 'Catalytic activity tests',
 'Catalytic reaction tests',
 'Catalytic activity measurements',
 'Catalytic activity tests',
 'Activity measurements',
 'Characterizations and reactivity studies',
 'Activity evaluation',
 'Catalytic test',
 'Catalytic performance test',
 'Catalytic activity',
 'Catalyst performance',
 'Activity for reactions',
 'Activity testing',
 'Catalytic activity measurement',
 'Activity measurements',
 'Catalytic activity',
 'Catalytic tests',
 'Activity measurements',
 'Activity tests',
 'NH',
 'Catalyst activity measurement',
 'Catalytic tests',
 'Catalyst evaluation',
 'Activity test',
 'Catalytic activity measurement',
 'Catalytic activity test',
 'Catalytic activity evaluation',
 'Catalytic performance test',
 'Activity tests',
 'Photocatalytic NO',
 'Catalyst performance measurements',
 'Catalyst evaluation',
 'Catalyst evaluation',
 'Catalytic activity measurements',
 'Activity test',
 'Catalytic performance tests',
 'Catalytic tests',
 '没有的Catalytic performance',
 'Catalytic performance test',
 'Catalytic activity testing',
 'Activity test',
 'Catalytic activity testing',
 'Activity test',
 'Measurement of catalytic activity',
 'Catalytic performance evaluation',
 'Catalytic performance',
 'Catalytic activity testing',
 'Catalyst test',
 'Catalyst evaluation',
 'Catalyst test bench measurements',
 'NO',
 'Activity test in the NH',
 'Catalytic performance evaluation',
 'Catalytic tests',
 'Activity, selectivity and stability of the catalysts',
 'Catalytic activity of Rh/Ce',
 'Catalytic tests',
 'Catalytic activity measurements',
 'Catalytic performance',
 'NH',
 'Activity measurements',
 'Catalytic activity measurement',
 'Catalytic performance testing',
 'Activity measurement',
 'Catalytic activity measurements',
 'Catalyst activity measurements',
 'Catalyst activity test',
 'Catalytic performance measurement',
 'Catalytic activity measurements',
 'Catalytic and kinetic tests',
 'Catalytic activity measurement',
 'Catalytic tests',
 'Activity test',
 'Activity evaluation',
 'Activity tests',
 'Catalytic performance tests',
 'Catalytic activity testing',
 'Catalyst activity',
 'Catalytic activity measurements',
 'Activity measurements and evaluation',
 'Examination of catalytic activity',
 'Catalytic activity',
 'Catalytic performance',
 'Catalytic activity test',
 'Catalytic activity and selectivity test',
 'Catalytic activity measurement',
 '没有的Evidence for catalytic activity',
 'Catalytic activity measurement',
 'Experimental setup and analysis',
 'Catalytic activity tests',
 'Catalytic performance measurements',
 'Catalytic activity determination',
 'Activity tests',
 'Catalytic performance testing: plasma reactor system',
 'Activity test',
 'Catalytic performance test',
 'Activity studies',
 'Catalytic activity',
 'Catalytic activity tests',
 'SCR activity tests and measurements',
 'Catalytic activity test',
 'Catalytic reactions',
 'Catalytic tests',
 'Catalytic activity tests',
 'Catalytic activity tests',
 'Catalyst tests',
 'Catalytic activity measurement',
 'Catalytic activity measurements',
 'Catalytic experiment',
 'Evaluation of Catalytic Activity',
 'Catalytic activity tests',
 'Catalytic activity measurement',
 'Catalytic activity',
 'Catalytic activity measurement',
 'N',
 'Activity evaluation',
 'Catalytic activity measurement',
 'Performance evaluation of Hg',
 'Catalytic activity tests',
 'Catalytic study',
 'Activity measurements',
 'Catalysts activity measurements',
 'Activity tests',
 'Catalytic performance tests',
 'Activity test',
 'Catalytic activity measurement',
 'Catalyst activity measurement',
 'Catalytic activity tests',
 'Catalyst activity measurements',
 'Photocatalytic reaction',
 'Catalytic activity tests',
 'Catalytic performance measurement',
 'Catalytic activity measurement',
 'Active species scavenger tests',
 'Catalytic activity measurements',
 'Catalytic activity tests',
 'Activity measurement',
 'Catalytic activity measurement',
 'Activity tests',
 'Catalysis',
 'Catalytic activity in the NOx reduction (NH',
 'NH',
 'Catalytic Activity Test',
 'Catalytic activity testing',
 'Catalytic activity measurement',
 'Catalytic activity testing',
 'Activity test',
 'Performance evaluation',
 'Catalytic and adsorption activity measurement',
 'Laboratory-scale experimental setup',
 'Catalytic activity measurement',
 'Catalytic activity tests',
 'Activity measurement',
 'Catalytic activity measurement',
 'Catalytic activity tests',
 'Catalytic activities',
 'Catalytic activity test',
 'Catalytic performance tests',
 'Catalytic activity test for the NO–CO reaction',
 'Catalytic activity testing',
 'Catalytic activity testing',
 'Catalytic performance test for selective catalytic reduction on NO',
 'Catalytic test',
 'Catalytic activity tests',
 'Activity evaluation',
 'Catalytic activity measurement',
 'Measurement of catalytic activity',
 'Catalytic tests',
 'Catalyst activity measurements',
 'Catalytic reaction',
 'Catalytic activity test',
 'The catalytic performance tests',
 'Catalytic activity test',
 'Experimental setup',
 'Activity measurement',
 'Catalytic activity measurement',
 'SCR activity measurements',
 'Catalysis measurements',
 'Catalytic testing',
 'Catalyst activity test',
 'Catalytic activity measurement',
 'Catalytic performance tests',
 'Catalytic performance',
 'Catalyst performance tests',
 'Catalytic activity of IOR and Mn',
 'Experimental details',
 'Catalytic activity tests',
 '没有的Catalytic stability',
 'Catalytic activity test',
 'Plasma-catalytic system',
 'Activity test',
 'NH',
'Evaluation of catalyst activity',
'Activity tests',
'Catalytic activity measurement',
'HC-SCR catalyst',
'Reactivity experiments',
'Catalytic tests',
'Activity tests',
'Catalytic performance measurements',
'Activity measurements',
'Activity measurement',
'Catalysis',
'Catalytic activity test',
'‘Steady-state’ testing (Pacific Northwest National Laboratory)',
'Catalytic activity measurement',
'Catalytic conversion of NO with propene (HC-SCR DeNO',
'Catalytic tests',
'Catalyst performance',
'Catalytic activity measurement',
'Catalysis measurements',
'Catalyst activity tests',
'Reactor system',
'Catalytic activity determination',
'Catalytic activity measurement',
'Catalytic tests',
'Catalytic activity and N',
'Catalytic activity measurement',
'NH',
'NO',
'NH',
'Catalytic test',
'Catalytic activity tests',
'NH',
'Catalytic activity testing',
'Experimental procedure',
'Activity test',
'Catalytic activity measurements',
'没有的Catalytic reduction of CO',
'Catalytic activity tests',
'Catalytic activity tests',
'Activity measurement',
'Catalyst testing system',
'Reaction studies',
'Evaluation of catalytic performance',
'Catalytic performance test',
'Activity measurement',
'Catalytic activity testing',
'Catalytic reduction of NO',
'NH',
'Catalytic activity tests for NO reduction',
'Catalytic activity measurement',
'Activity measurements',
'Catalyst activity test',
'Activity and transient response tests',
'Catalytic measurement',
'Catalytic activity measurements',
'Catalytic activity',
'Catalyst evaluation',
'Catalytic tests',
'Catalyst testing',
'Characterization and activity measurement',
'Activity tests',
'Activity measurements',
'Activity tests',
'Catalytic activity measurement',
'Catalyst activity evaluation',
'Activity tests',
'Activity tests',
'Catalytic tests',
'Catalytic test',
'Catalyst evaluation',
'Catalytic performance test',
'Catalytic activity tests',
'Catalytic activity test',
'Catalytic activity tests',
'Catalytic performance measurement',
'Catalytic activity measurement',
'Catalyst activity testing',
'Catalytic activity measurements',
'Catalytic activity measurements',
'Catalyst activity test',
'Catalytic performance',
'Flow reactor tests',
'Catalyst performance evaluation',
'Catalytic activity measurement',
'Catalyst activity measurements',
'Experiment system',
'Reaction studies',
'SCR activity measurements',
'Catalytic activity measurement',
'NH',
'Catalyst activity',
'Catalytic properties measurements',
'Catalytic activity valuation',
'Catalytic activity measurements',
'Activity evaluation',
'Catalytic activity test',
'Morphology and textural analysis',
'Catalytic activity and selectivity measurement',
'Catalytic activity test']

# %%
len(reaction_titles)
# Out:
# 446

# %%
xml_folder = './SCR_xml_446'

# %%
import os
import pandas as pd
import re
import  xml.etree.ElementTree as ET
import pandas as pd

# %%
import xml.etree.ElementTree as ET
import os
for i in range(len(reaction_titles)):
    xml_file = xml_files2[i]
    file_path = os.path.join(xml_folder, xml_file)
    tree = ET.ElementTree(file=file_path)
    root = tree.getroot()
    
    title = reaction_titles[0]  # 假设 reaction_titles 是你要查找的标题列表

    # 遍历每个ce:section元素
    for section in root.findall(".//{http://www.elsevier.com/xml/common/dtd}section"):
        # 获取section-title元素的文本内容
        section_title = section.find("{http://www.elsevier.com/xml/common/dtd}section-title").text
        # 如果section_title为目标标题，则提取文本内容
        if section_title == title:
            # 遍历section中的所有文本元素，去除标签，保留文本
            for para in section.findall("{http://www.elsevier.com/xml/common/dtd}para"):
                # 提取段落文本
                text = ''.join(para.itertext())
                
                # 清理多余空白符号
                cleaned_text = text.replace('\n', ' ').replace('\r', '').strip()
                
                # 去掉不必要的符号（如方括号等）
                cleaned_text = cleaned_text.replace('[', '').replace(']', '')

                # 输出清理后的文本
                print(cleaned_text)
# Out:
# The C2H2-SCR reaction was carried out in a quartz reactor (i.d. 4mm) at atmospheric pressure. A mixture of 1600ppm NO, 800ppm C2H2, 10% O2 in He with a total flow rate of 50mlmin−1 was fed through 0.2g catalyst (GHSV≈ 8000h−1). NO conversion was calculated from the amount of produced N2 as analyzed by GC (HP 6890) using a capillary column (HP–PLOT/zeolite 30m×0.32mm×12μm). For comparison, 1600ppm of CH4 and 533ppm of C3H6 (in the same carbon concentration) were used as reductant instead of C2H2.
# ...

# %%
len(reaction_titles)
# Out:
# 446

# %%
import xml.etree.ElementTree as ET
import os
reaction_folder = '/SCR_reation_446/'

successful_files = []
unsuccessful_files = []
for i in range(len(reaction_titles)):
    xml_file = xml_files2[i]
    file_path = os.path.join(xml_folder, xml_file)
    tree = ET.ElementTree(file=file_path)
    root = tree.getroot()
    title = reaction_titles[i] 
    for section in root.findall(".//{http://www.elsevier.com/xml/common/dtd}section"):
      
        section_title = section.find("{http://www.elsevier.com/xml/common/dtd}section-title").text
     
        if section_title == title:

            for para in section.findall("{http://www.elsevier.com/xml/common/dtd}para"):
         
                text = ''.join(para.itertext())
                text = text.replace('\n\n','\n')
                cleaned_text = text.replace('\n', ' ').replace('\r', '').strip()
    if cleaned_text:
        output_file = os.path.splitext(xml_file)[0] + '.txt'
        output_path = os.path.join(reaction_folder, output_file)
        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(cleaned_text)  #
        successful_files.append(xml_file)
        #print(f"提取内容已保存到 {output_path}")
    else:
        print(f"未能从 {xml_file} 提取到段落。")
        unsuccessful_files.append(xml_file)
